# %%
import sys
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import random
# %matplotlib inline

# %%
import torch
from torch import nn
from torch import distributions
from torch.nn.parameter import Parameter
from train import train
from train import train_rnis
from models_new import Renorm_Dynamic
from models_new import Rnis_Dynamic
from ei.EI_calculation import count_parameters
from dynamic_models_sis_new import Simple_Spring_Model
from datetime import datetime
t0 = datetime.now()


use_cuda = torch.cuda.is_available()
device = torch.device('cuda:0') if use_cuda else torch.device('cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Generate data

# %%
mul_batch_size = [0,5000,3000,1000]#[0,10,4500,1500]
sigma = 0.03
rou = -0.5
steps = 7
dt = 0.01

seed = 2050
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
spring = Simple_Spring_Model(device=device)
test_data = spring.generate_multistep_sir(size_list=[500,500], steps=10, sigma=sigma, rou=rou,lam=1,miu=0.5,dt=dt) 
train_data = spring.generate_multistep_sir(size_list=mul_batch_size, steps=steps, sigma=sigma,rou=rou,lam=1,miu=0.5,dt=dt)

# %% [markdown]
# # Train RNIS

# %%
sz = 4
scale = 2
L = 1
mae2_w = 3
T_total = 30001
eis_rnis, term1s_rnis, term2s_rnis, losses_rnis, MAEs_mstep_rnis, net_rnis = train_rnis(train_data=train_data, test_data=test_data, 
                                                                    sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                    mae2_w=mae2_w, dt=dt, T2=T_total)
count_parameters(net_rnis)
# Out:
# check point-------o_0-> 16:59:31.855712; lasting 0:00:05.164688 seconds
# Epoch: 0
# Train loss: 0.4519
# dEI: 0.4148
# term1: -0.4372
# term2: 1.2669
# Test multistep loss: 0.5445
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 16:59:39.227315; lasting 0:00:07.371603 seconds
# check point-------o_0-> 16:59:48.374060; lasting 0:00:09.146745 seconds
# Epoch: 500
# Train loss: 0.0627
# dEI: 1.3171
# term1: 1.3027
# term2: 1.3315
# Test multistep loss: 0.0714
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:00:00.006159; lasting 0:00:11.632099 seconds
# check point-------o_0-> 17:00:07.156122; lasting 0:00:07.149963 seconds
# Epoch: 1000
# Train loss: 0.0358
# dEI: 1.7008
# term1: 2.0568
# term2: 1.3448
# Test multistep loss: 0.0383
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:00:20.785292; lasting 0:00:13.629170 seconds
# check point-------o_0-> 17:00:28.584050; lasting 0:00:07.798758 seconds
# Epoch: 1500
# Train loss: 0.0317
# dEI: 1.8109
# term1: 2.2680
# term2: 1.3538
# Test multistep loss: 0.0321
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:00:43.038232; lasting 0:00:14.454182 seconds
# check point-------o_0-> 17:00:50.630392; lasting 0:00:07.592160 seconds
# Epoch: 2000
# Train loss: 0.0317
# dEI: 1.8646
# term1: 2.3710
# term2: 1.3581
# Test multistep loss: 0.0398
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:01:06.045279; lasting 0:00:15.414887 seconds
# check point-------o_0-> 17:01:15.622134; lasting 0:00:09.576855 seconds
# Epoch: 2500
# Train loss: 0.0307
# dEI: 1.9166
# term1: 2.4661
# term2: 1.3670
# Test multistep loss: 0.0304
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:01:29.140459; lasting 0:00:13.518325 seconds
# check point-------o_0-> 17:01:38.499437; lasting 0:00:09.358978 seconds
# Epoch: 3000
# Train loss: 0.0308
# dEI: 1.9533
# term1: 2.5385
# term2: 1.3681
# Test multistep loss: 0.0321
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:01:51.795434; lasting 0:00:13.295997 seconds
# check point-------o_0-> 17:02:08.636806; lasting 0:00:16.841372 seconds
# Epoch: 3500
# Train loss: 0.0310
# dEI: 2.0487
# term1: 2.7234
# term2: 1.3739
# Test multistep loss: 0.0374
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:02:22.059862; lasting 0:00:13.423056 seconds
# check point-------w_0-> 17:02:38.416189; lasting 0:00:16.356327 seconds
# check point-------w_1-> 17:02:38.446988; lasting 0:00:00.030799 seconds
# check point-------w_2-> 17:08:33.984663; lasting 0:05:55.537675 seconds
# check point-------w_3-> 17:08:34.017180; lasting 0:00:00.032517 seconds
# check point-------o_0-> 17:08:34.017279; lasting 0:00:00.000099 seconds
# Epoch: 4000
# Train loss: 0.0305
# dEI: 2.1189
# term1: 2.8623
# term2: 1.3755
# Test multistep loss: 0.0423
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:08:46.471606; lasting 0:00:12.454327 seconds
# check point-------o_0-> 17:08:59.453749; lasting 0:00:12.982143 seconds
# Epoch: 4500
# Train loss: 0.0290
# dEI: 2.1638
# term1: 2.9555
# term2: 1.3721
# Test multistep loss: 0.0322
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:09:15.697126; lasting 0:00:16.243377 seconds
# check point-------w_0-> 17:09:27.686930; lasting 0:00:11.989804 seconds
# check point-------w_1-> 17:09:27.708667; lasting 0:00:00.021737 seconds
# check point-------w_2-> 17:15:23.169352; lasting 0:05:55.460685 seconds
# check point-------w_3-> 17:15:23.183313; lasting 0:00:00.013961 seconds
# check point-------o_0-> 17:15:23.183368; lasting 0:00:00.000055 seconds
# Epoch: 5000
# Train loss: 0.0307
# dEI: 2.2198
# term1: 3.0798
# term2: 1.3598
# Test multistep loss: 0.0358
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:15:38.827757; lasting 0:00:15.644389 seconds
# check point-------o_0-> 17:15:59.652542; lasting 0:00:20.824785 seconds
# Epoch: 5500
# Train loss: 0.0292
# dEI: 2.2535
# term1: 3.1492
# term2: 1.3578
# Test multistep loss: 0.0325
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:16:15.594208; lasting 0:00:15.941666 seconds
# check point-------w_0-> 17:16:37.318885; lasting 0:00:21.724677 seconds
# check point-------w_1-> 17:16:37.344506; lasting 0:00:00.025621 seconds
# check point-------w_2-> 17:23:14.668886; lasting 0:06:37.324380 seconds
# check point-------w_3-> 17:23:14.672576; lasting 0:00:00.003690 seconds
# check point-------o_0-> 17:23:14.672624; lasting 0:00:00.000048 seconds
# Epoch: 6000
# Train loss: 0.0293
# dEI: 2.2833
# term1: 3.2165
# term2: 1.3500
# Test multistep loss: 0.0330
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:23:31.811360; lasting 0:00:17.138736 seconds
# check point-------o_0-> 17:23:43.846623; lasting 0:00:12.035263 seconds
# Epoch: 6500
# Train loss: 0.0287
# dEI: 2.3022
# term1: 3.2556
# term2: 1.3488
# Test multistep loss: 0.0296
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:23:58.455643; lasting 0:00:14.609020 seconds
# check point-------w_0-> 17:24:14.011538; lasting 0:00:15.555895 seconds
# check point-------w_1-> 17:24:14.034919; lasting 0:00:00.023381 seconds
# check point-------w_2-> 17:30:50.249861; lasting 0:06:36.214942 seconds
# check point-------w_3-> 17:30:50.267378; lasting 0:00:00.017517 seconds
# check point-------o_0-> 17:30:50.267458; lasting 0:00:00.000080 seconds
# Epoch: 7000
# Train loss: 0.0298
# dEI: 2.3432
# term1: 3.3342
# term2: 1.3522
# Test multistep loss: 0.0334
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:31:05.753172; lasting 0:00:15.485714 seconds
# check point-------o_0-> 17:31:26.158203; lasting 0:00:20.405031 seconds
# Epoch: 7500
# Train loss: 0.0290
# dEI: 2.3509
# term1: 3.3465
# term2: 1.3554
# Test multistep loss: 0.0362
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:31:42.345405; lasting 0:00:16.187202 seconds
# check point-------w_0-> 17:32:02.848425; lasting 0:00:20.503020 seconds
# check point-------w_1-> 17:32:02.862399; lasting 0:00:00.013974 seconds
# check point-------w_2-> 17:38:27.834283; lasting 0:06:24.971884 seconds
# check point-------w_3-> 17:38:27.842708; lasting 0:00:00.008425 seconds
# check point-------o_0-> 17:38:27.842781; lasting 0:00:00.000073 seconds
# Epoch: 8000
# Train loss: 0.0295
# dEI: 2.3895
# term1: 3.4183
# term2: 1.3608
# Test multistep loss: 0.0313
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:38:45.195258; lasting 0:00:17.352477 seconds
# check point-------o_0-> 17:38:58.684751; lasting 0:00:13.489493 seconds
# Epoch: 8500
# Train loss: 0.0291
# dEI: 2.4037
# term1: 3.4488
# term2: 1.3586
# Test multistep loss: 0.0295
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:39:14.810150; lasting 0:00:16.125399 seconds
# check point-------w_0-> 17:39:33.023517; lasting 0:00:18.213367 seconds
# check point-------w_1-> 17:39:33.044201; lasting 0:00:00.020684 seconds
# check point-------w_2-> 17:46:39.165153; lasting 0:07:06.120952 seconds
# check point-------w_3-> 17:46:39.170525; lasting 0:00:00.005372 seconds
# check point-------o_0-> 17:46:39.170610; lasting 0:00:00.000085 seconds
# Epoch: 9000
# Train loss: 0.0287
# dEI: 2.4226
# term1: 3.4903
# term2: 1.3548
# Test multistep loss: 0.0323
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:46:51.667057; lasting 0:00:12.496447 seconds
# check point-------o_0-> 17:47:07.964796; lasting 0:00:16.297739 seconds
# Epoch: 9500
# Train loss: 0.0292
# dEI: 2.4423
# term1: 3.5302
# term2: 1.3543
# Test multistep loss: 0.0329
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:47:23.372144; lasting 0:00:15.407348 seconds
# check point-------w_0-> 17:47:40.655558; lasting 0:00:17.283414 seconds
# check point-------w_1-> 17:47:40.672645; lasting 0:00:00.017087 seconds
# check point-------w_2-> 17:54:02.976228; lasting 0:06:22.303583 seconds
# check point-------w_3-> 17:54:02.979962; lasting 0:00:00.003734 seconds
# check point-------o_0-> 17:54:02.980012; lasting 0:00:00.000050 seconds
# Epoch: 10000
# Train loss: 0.0295
# dEI: 2.4674
# term1: 3.5818
# term2: 1.3530
# Test multistep loss: 0.0311
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:54:18.552101; lasting 0:00:15.572089 seconds
# check point-------o_0-> 17:54:38.891631; lasting 0:00:20.339530 seconds
# Epoch: 10500
# Train loss: 0.0287
# dEI: 2.4508
# term1: 3.5598
# term2: 1.3419
# Test multistep loss: 0.0292
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:54:55.167418; lasting 0:00:16.275787 seconds
# check point-------w_0-> 17:55:16.260589; lasting 0:00:21.093171 seconds
# check point-------w_1-> 17:55:16.285671; lasting 0:00:00.025082 seconds
# check point-------w_2-> 18:01:59.324787; lasting 0:06:43.039116 seconds
# check point-------w_3-> 18:01:59.328784; lasting 0:00:00.003997 seconds
# check point-------o_0-> 18:01:59.328836; lasting 0:00:00.000052 seconds
# Epoch: 11000
# Train loss: 0.0284
# dEI: 2.4711
# term1: 3.5939
# term2: 1.3483
# Test multistep loss: 0.0287
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:02:14.004745; lasting 0:00:14.675909 seconds
# check point-------o_0-> 18:02:29.406630; lasting 0:00:15.401885 seconds
# Epoch: 11500
# Train loss: 0.0293
# dEI: 2.5005
# term1: 3.6573
# term2: 1.3436
# Test multistep loss: 0.0290
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:02:46.529608; lasting 0:00:17.122978 seconds
# Train loss: 0.0291
# dEI: 2.5220
# term1: 3.7008
# term2: 1.3432
# Test multistep loss: 0.0286
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:10:38.578341; lasting 0:00:16.017452 seconds
# check point-------w_0-> 18:10:57.885748; lasting 0:00:19.307407 seconds
# check point-------w_1-> 18:10:57.896811; lasting 0:00:00.011063 seconds
# check point-------w_2-> 18:17:21.793702; lasting 0:06:23.896891 seconds
# check point-------w_3-> 18:17:21.797378; lasting 0:00:00.003676 seconds
# check point-------o_0-> 18:17:21.797431; lasting 0:00:00.000053 seconds
# Epoch: 13000
# Train loss: 0.0286
# dEI: 2.5294
# term1: 3.7047
# term2: 1.3541
# Test multistep loss: 0.0358
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:17:36.491977; lasting 0:00:14.694546 seconds
# check point-------o_0-> 18:17:53.659552; lasting 0:00:17.167575 seconds
# Epoch: 13500
# check point-------w_2-> 18:24:43.633480; lasting 0:06:17.108994 seconds
# check point-------w_3-> 18:24:43.640791; lasting 0:00:00.007311 seconds
# check point-------o_0-> 18:24:43.640882; lasting 0:00:00.000091 seconds
# Epoch: 14000
# Train loss: 0.0288
# dEI: 2.5438
# term1: 3.7341
# term2: 1.3535
# Test multistep loss: 0.0394
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:25:02.158162; lasting 0:00:18.517280 seconds
# check point-------o_0-> 18:25:18.538998; lasting 0:00:16.380836 seconds
# Epoch: 14500
# Train loss: 0.0287
# dEI: 2.5629
# term1: 3.7766
# term2: 1.3492
# Test multistep loss: 0.0340
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:25:34.234025; lasting 0:00:15.695027 seconds
# check point-------w_0-> 18:25:51.353360; lasting 0:00:17.119335 seconds
# check point-------w_1-> 18:25:51.371853; lasting 0:00:00.018493 seconds
# check point-------w_2-> 18:31:58.782365; lasting 0:06:07.410512 seconds
# check point-------w_3-> 18:31:58.789488; lasting 0:00:00.007123 seconds
# check point-------o_0-> 18:31:58.789532; lasting 0:00:00.000044 seconds
# Epoch: 15000
# Train loss: 0.0290
# dEI: 2.5542
# term1: 3.7538
# term2: 1.3545
# Test multistep loss: 0.0322
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:32:15.630964; lasting 0:00:16.841432 seconds
# check point-------o_0-> 18:32:28.028417; lasting 0:00:12.397453 seconds
# Epoch: 15500
# Train loss: 0.0283
# dEI: 2.5744
# term1: 3.7997
# term2: 1.3492
# Test multistep loss: 0.0309
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:32:42.544800; lasting 0:00:14.516383 seconds
# check point-------w_0-> 18:32:57.487545; lasting 0:00:14.942745 seconds
# check point-------w_1-> 18:32:57.512626; lasting 0:00:00.025081 seconds
# check point-------w_2-> 18:39:56.722373; lasting 0:06:59.209747 seconds
# check point-------w_3-> 18:39:56.729679; lasting 0:00:00.007306 seconds
# check point-------o_0-> 18:39:56.729727; lasting 0:00:00.000048 seconds
# Epoch: 16000
# Train loss: 0.0282
# dEI: 2.5912
# term1: 3.8315
# term2: 1.3508
# Test multistep loss: 0.0344
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:40:12.846781; lasting 0:00:16.117054 seconds
# check point-------o_0-> 18:40:31.164720; lasting 0:00:18.317939 seconds
# Epoch: 16500
# Train loss: 0.0286
# dEI: 2.5900
# term1: 3.8298
# term2: 1.3501
# Test multistep loss: 0.0372
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 18:40:46.213270; lasting 0:00:15.048550 seconds
# check point-------w_2-> 20:01:56.904362; lasting 0:07:00.535056 seconds
# check point-------w_3-> 20:01:56.909838; lasting 0:00:00.005476 seconds
# check point-------o_0-> 20:01:56.909913; lasting 0:00:00.000075 seconds
# Epoch: 26000

# %% [markdown]
# # Train NIS

# %%
sz = 4
scale = 2
L = 1
mae2_w = 3
T_total = 30001
eis_nis, term1s_nis, term2s_nis, losses_nis, MAEs_mstep_nis, net_nis = train(train_data=train_data, test_data=test_data, 
                                                                    sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                    mae2_w=mae2_w, dt=dt, T2=T_total,framework='nis')

# %% [markdown]
# # Train NIS+

# %%
eis_nisp, term1s_nisp, term2s_nisp, losses_nisp, MAEs_mstep_nisp, net_nisp = train(train_data=train_data, test_data=test_data, 
                                                                         sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                         mae2_w=mae2_w, dt=dt, T2=T_total,framework='nis+')

# %% [markdown]
# # Results

# %%
print(count_parameters(net_rnis),count_parameters(net_nis),count_parameters(net_nisp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(count_parameters(net_rnis),count_parameters(net_nis),count_parameters(net_nisp))
#
# NameError: name 'net_nis' is not defined

# %%
plt.figure(dpi=300)
timeseries = np.arange(len(eis_nis))*500
plt.plot(timeseries, eis_nis, label='NIS')
plt.plot(timeseries, eis_nisp, label='NIS+')
plt.plot(timeseries, eis_rnis, label='RNIS')
plt.title(r'$\mathcal{J}$')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(dpi=300)
# ----> 2 timeseries = np.arange(len(eis_nis))*500
#       3 plt.plot(timeseries, eis_nis, label='NIS')
#       4 plt.plot(timeseries, eis_nisp, label='NIS+')
#
# NameError: name 'eis_nis' is not defined

# %%
plt.figure(dpi=300)
timeseries = np.arange(len(eis_nis))*500
plt.plot(timeseries, losses_nis, label='NIS')
plt.plot(timeseries, losses_nisp, label='NIS+')
plt.plot(timeseries, losses_rnis, label='RNIS')
plt.title(r'loss')
plt.legend()
#plt.yscale('log')
plt.show()

# %%
plt.figure(dpi=300)
timeseries = np.arange(len(eis_nis))*500
plt.plot(timeseries, MAEs_mstep_nis, label='NIS')
plt.plot(timeseries, MAEs_mstep_nisp, label='NIS+')
plt.plot(timeseries, MAEs_mstep_rnis, label='RNIS')
plt.title(r'multistep mae')
plt.legend()
plt.show()
