# %% [markdown]
# # Import backage

# %%
import sys
sys.path.append("../..")
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import random
# %matplotlib inline

# %%
import torch
from torch import nn
from torch import distributions
from torch.nn.parameter import Parameter
from train import train
from models.models_new import Renorm_Dynamic
from dynamic_models_sis_new import Simple_Spring_Model
from sklearn.neighbors import NearestNeighbors
from sklearn.neighbors import KernelDensity
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from datetime import datetime
t0 = datetime.now()


use_cuda = torch.cuda.is_available()
device = torch.device('cuda:0') if use_cuda else torch.device('cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Five parallel experiments

# %%
# part samples
experiments = 5
mul_batch_size = [0,10,4500,1500]
sigma = 0.03
rou = -0.5
steps = 7
sz = 4
scale = 2
L = 1
mae2_w = 3
T_total = 30001

eis_nis_e = np.zeros([experiments,T_total//500+1])
losses_nis_e = np.zeros([experiments,T_total//500+1])
MAEs_mstep_nis_e = np.zeros([experiments,T_total//500+1])
eis_nisp_e = np.zeros([experiments,T_total//500+1])
losses_nisp_e = np.zeros([experiments,T_total//500+1])
MAEs_mstep_nisp_e = np.zeros([experiments,T_total//500+1])

# %%
# nis
for e in range(experiments):
    seed = 1 + e
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    spring = Simple_Spring_Model(device=device)
    test_data = spring.generate_multistep_sir(size_list=[500,500], steps=10, sigma=sigma, rou=rou,lam=1,miu=0.5,dt=0.01) #sir
    train_data = spring.generate_multistep_sir(size_list=mul_batch_size, steps=steps, sigma=sigma,rou=rou,lam=1,miu=0.5,dt=0.01)
    
    eis_nis, term1s_nis, term2s_nis, losses_nis, MAEs_mstep_nis = train(train_data=train_data, test_data=test_data, 
                                                                    sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                    mae2_w=mae2_w, T2=T_total,framework='nis')
    eis_nis_e[e,:] = eis_nis
    losses_nis_e[e,:] = losses_nis
    MAEs_mstep_nis_e[e,:] = MAEs_mstep_nis
# Out:
# check point-------o_0-> 17:33:10.108008; lasting 0:01:07.363151 seconds
# Epoch: 0
# Train loss: 0.5174
# dEI: 0.3344
# term1: -0.7183
# term2: 1.3871
# Test multistep loss: 0.6344
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:33:15.363449; lasting 0:00:05.255441 seconds
# check point-------o_0-> 17:33:22.492798; lasting 0:00:07.129349 seconds
# Epoch: 500
# Train loss: 0.0769
# dEI: 1.3173
# term1: 0.9763
# term2: 1.6584
# Test multistep loss: 0.0981
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:33:29.428341; lasting 0:00:06.935543 seconds
# check point-------o_0-> 17:33:37.167722; lasting 0:00:07.739381 seconds
# Epoch: 1000
# Train loss: 0.0360
# dEI: 1.7664
# term1: 1.8401
# term2: 1.6927
# Test multistep loss: 0.0592
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:33:47.574351; lasting 0:00:10.406629 seconds
# check point-------o_0-> 17:33:56.030552; lasting 0:00:08.456201 seconds
# Epoch: 1500
# Train loss: 0.0330
# dEI: 1.8505
# term1: 2.0179
# term2: 1.6831
# Test multistep loss: 0.0529
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:34:04.500404; lasting 0:00:08.469852 seconds
# check point-------o_0-> 17:34:12.017212; lasting 0:00:07.516808 seconds
# Epoch: 2000
# Train loss: 0.0312
# dEI: 1.9627
# term1: 2.2479
# term2: 1.6775
# Test multistep loss: 0.0396
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:34:20.763245; lasting 0:00:08.746033 seconds
# check point-------o_0-> 17:34:26.038136; lasting 0:00:05.274891 seconds
# Epoch: 2500
# Train loss: 0.0300
# dEI: 2.0353
# term1: 2.4065
# term2: 1.6640
# Test multistep loss: 0.0425
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:34:34.873338; lasting 0:00:08.835202 seconds
# check point-------o_0-> 17:34:43.140476; lasting 0:00:08.267138 seconds
# Epoch: 3000
# Train loss: 0.0312
# dEI: 2.0769
# term1: 2.4941
# term2: 1.6598
# Test multistep loss: 0.0479
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:34:52.051752; lasting 0:00:08.911276 seconds
# check point-------o_0-> 17:34:57.331204; lasting 0:00:05.279452 seconds
# Epoch: 3500
# Train loss: 0.0289
# dEI: 2.1260
# term1: 2.5976
# term2: 1.6545
# Test multistep loss: 0.0397
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:35:06.224657; lasting 0:00:08.893453 seconds
# check point-------o_0-> 17:35:11.500235; lasting 0:00:05.275578 seconds
# Epoch: 4000
# Train loss: 0.0293
# dEI: 2.1587
# term1: 2.6647
# term2: 1.6527
# Test multistep loss: 0.0365
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:35:20.470218; lasting 0:00:08.969983 seconds
# check point-------o_0-> 17:35:25.751280; lasting 0:00:05.281062 seconds
# Epoch: 4500
# Train loss: 0.0299
# dEI: 2.1652
# term1: 2.6771
# term2: 1.6533
# Test multistep loss: 0.0443
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:35:34.738587; lasting 0:00:08.987307 seconds
# check point-------o_0-> 17:35:40.014723; lasting 0:00:05.276136 seconds
# Epoch: 5000
# Train loss: 0.0299
# dEI: 2.2182
# term1: 2.7944
# term2: 1.6420
# Test multistep loss: 0.0375
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:35:48.992001; lasting 0:00:08.977278 seconds
# check point-------o_0-> 17:35:54.253541; lasting 0:00:05.261540 seconds
# Epoch: 5500
# Train loss: 0.0303
# dEI: 2.2526
# term1: 2.8655
# term2: 1.6397
# Test multistep loss: 0.0304
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:36:03.299734; lasting 0:00:09.046193 seconds
# check point-------o_0-> 17:36:08.577317; lasting 0:00:05.277583 seconds
# Epoch: 6000
# Train loss: 0.0288
# dEI: 2.2677
# term1: 2.9004
# term2: 1.6351
# Test multistep loss: 0.0356
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:36:17.890871; lasting 0:00:09.313554 seconds
# check point-------o_0-> 17:36:26.307966; lasting 0:00:08.417095 seconds
# Epoch: 6500
# Train loss: 0.0300
# dEI: 2.2895
# term1: 2.9482
# term2: 1.6307
# Test multistep loss: 0.0388
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:36:35.300954; lasting 0:00:08.992988 seconds
# check point-------o_0-> 17:36:40.570842; lasting 0:00:05.269888 seconds
# Epoch: 7000
# Train loss: 0.0293
# dEI: 2.2990
# term1: 2.9714
# term2: 1.6265
# Test multistep loss: 0.0336
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:36:49.622082; lasting 0:00:09.051240 seconds
# check point-------o_0-> 17:36:54.886951; lasting 0:00:05.264869 seconds
# Epoch: 7500
# Train loss: 0.0299
# dEI: 2.3034
# term1: 2.9807
# term2: 1.6262
# Test multistep loss: 0.0324
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:37:03.908981; lasting 0:00:09.022030 seconds
# check point-------o_0-> 17:37:09.162681; lasting 0:00:05.253700 seconds
# Epoch: 8000
# Train loss: 0.0289
# dEI: 2.3266
# term1: 3.0228
# term2: 1.6305
# Test multistep loss: 0.0350
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:37:18.242587; lasting 0:00:09.079906 seconds
# check point-------o_0-> 17:37:23.531037; lasting 0:00:05.288450 seconds
# Epoch: 8500
# Train loss: 0.0291
# dEI: 2.3357
# term1: 3.0467
# term2: 1.6246
# Test multistep loss: 0.0304
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:37:32.578800; lasting 0:00:09.047763 seconds
# check point-------o_0-> 17:37:40.442834; lasting 0:00:07.864034 seconds
# Epoch: 9000
# Train loss: 0.0294
# dEI: 2.3567
# term1: 3.0923
# term2: 1.6211
# Test multistep loss: 0.0295
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:37:51.849443; lasting 0:00:11.406609 seconds
# check point-------o_0-> 17:37:59.398399; lasting 0:00:07.548956 seconds
# Epoch: 9500
# Train loss: 0.0297
# dEI: 2.3726
# term1: 3.1316
# term2: 1.6135
# Test multistep loss: 0.0350
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:38:10.783372; lasting 0:00:11.384973 seconds
# check point-------o_0-> 17:38:18.551494; lasting 0:00:07.768122 seconds
# Epoch: 10000
# Train loss: 0.0289
# dEI: 2.3677
# term1: 3.1232
# term2: 1.6122
# Test multistep loss: 0.0362
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:38:29.906449; lasting 0:00:11.354955 seconds
# check point-------o_0-> 17:38:37.666986; lasting 0:00:07.760537 seconds
# Epoch: 10500
# Train loss: 0.0292
# dEI: 2.3854
# term1: 3.1627
# term2: 1.6080
# Test multistep loss: 0.0304
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:38:48.950381; lasting 0:00:11.283395 seconds
# check point-------o_0-> 17:38:56.695616; lasting 0:00:07.745235 seconds
# Epoch: 11000
# Train loss: 0.0293
# dEI: 2.3950
# term1: 3.1883
# term2: 1.6016
# Test multistep loss: 0.0341
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:39:07.980567; lasting 0:00:11.284951 seconds
# check point-------o_0-> 17:39:15.136095; lasting 0:00:07.155528 seconds
# Epoch: 11500
# Train loss: 0.0294
# dEI: 2.3890
# term1: 3.1765
# term2: 1.6015
# Test multistep loss: 0.0348
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:39:26.417205; lasting 0:00:11.281110 seconds
# check point-------o_0-> 17:39:33.555510; lasting 0:00:07.138305 seconds
# Epoch: 12000
# Train loss: 0.0294
# dEI: 2.4175
# term1: 3.2393
# term2: 1.5957
# Test multistep loss: 0.0290
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:39:44.933279; lasting 0:00:11.377769 seconds
# check point-------o_0-> 17:39:52.116542; lasting 0:00:07.183263 seconds
# Epoch: 12500
# Train loss: 0.0293
# dEI: 2.4274
# term1: 3.2596
# term2: 1.5952
# Test multistep loss: 0.0391
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:40:03.480982; lasting 0:00:11.364440 seconds
# check point-------o_0-> 17:40:10.667518; lasting 0:00:07.186536 seconds
# Epoch: 13000
# Train loss: 0.0285
# dEI: 2.4327
# term1: 3.2754
# term2: 1.5899
# Test multistep loss: 0.0327
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:40:22.020414; lasting 0:00:11.352896 seconds
# check point-------o_0-> 17:40:29.196906; lasting 0:00:07.176492 seconds
# Epoch: 13500
# Train loss: 0.0294
# dEI: 2.4531
# term1: 3.3101
# term2: 1.5962
# Test multistep loss: 0.0313
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:40:40.535029; lasting 0:00:11.338123 seconds
# check point-------o_0-> 17:40:47.710705; lasting 0:00:07.175676 seconds
# Epoch: 14000
# Train loss: 0.0290
# dEI: 2.4220
# term1: 3.2523
# term2: 1.5917
# Test multistep loss: 0.0284
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:40:58.362345; lasting 0:00:10.651640 seconds
# check point-------o_0-> 17:41:06.057778; lasting 0:00:07.695433 seconds
# Epoch: 14500
# Train loss: 0.0282
# dEI: 2.4479
# term1: 3.3126
# term2: 1.5832
# Test multistep loss: 0.0296
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:41:17.512452; lasting 0:00:11.454674 seconds
# check point-------o_0-> 17:41:25.512398; lasting 0:00:07.999946 seconds
# Epoch: 15000
# Train loss: 0.0293
# dEI: 2.4462
# term1: 3.3115
# term2: 1.5810
# Test multistep loss: 0.0319
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:41:37.100987; lasting 0:00:11.588589 seconds
# check point-------o_0-> 17:44:25.648909; lasting 0:00:07.198050 seconds
# Epoch: 20000
# Train loss: 0.0285
# dEI: 2.4802
# term1: 3.4026
# term2: 1.5579
# Test multistep loss: 0.0335
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:44:37.151573; lasting 0:00:11.502664 seconds
# check point-------o_0-> 17:44:44.300725; lasting 0:00:07.149152 seconds
# Epoch: 20500
# Train loss: 0.0286
# dEI: 2.4785
# term1: 3.3972
# term2: 1.5597
# Test multistep loss: 0.0362
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:44:55.699694; lasting 0:00:11.398969 seconds
# check point-------o_0-> 17:45:03.310386; lasting 0:00:07.610692 seconds
# Epoch: 21000
# Train loss: 0.0286
# dEI: 2.4950
# term1: 3.4376
# term2: 1.5523
# Test multistep loss: 0.0321
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:45:14.776780; lasting 0:00:11.466394 seconds
# check point-------o_0-> 17:45:22.526467; lasting 0:00:07.749687 seconds
# Epoch: 21500
# Train loss: 0.0292
# dEI: 2.4875
# term1: 3.4245
# term2: 1.5505
# Test multistep loss: 0.0306
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:45:34.069070; lasting 0:00:11.542603 seconds
# check point-------o_0-> 17:45:41.815168; lasting 0:00:07.746098 seconds
# Epoch: 22000
# Train loss: 0.0280
# dEI: 2.4879
# term1: 3.4267
# term2: 1.5491
# Test multistep loss: 0.0297
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:45:50.949191; lasting 0:00:09.134023 seconds
# check point-------o_0-> 17:45:56.570840; lasting 0:00:05.621649 seconds
# Epoch: 22500
# Train loss: 0.0294
# dEI: 2.4809
# term1: 3.4161
# term2: 1.5457
# Test multistep loss: 0.0337
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:46:07.901730; lasting 0:00:11.330890 seconds
# check point-------o_0-> 17:46:15.065384; lasting 0:00:07.163654 seconds
# Epoch: 23000
# Train loss: 0.0294
# dEI: 2.4960
# term1: 3.4448
# term2: 1.5472
# Test multistep loss: 0.0315
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:46:26.450519; lasting 0:00:11.385135 seconds
# check point-------o_0-> 17:46:33.641435; lasting 0:00:07.190916 seconds
# Epoch: 23500
# Train loss: 0.0285
# dEI: 2.4896
# term1: 3.4290
# term2: 1.5501
# Test multistep loss: 0.0311
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:46:45.031814; lasting 0:00:11.390379 seconds
# check point-------o_0-> 17:46:52.281276; lasting 0:00:07.249462 seconds
# Epoch: 24000
# Train loss: 0.0286
# dEI: 2.4949
# term1: 3.4377
# term2: 1.5521
# Test multistep loss: 0.0356
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:47:03.603530; lasting 0:00:11.322254 seconds
# check point-------o_0-> 17:47:11.351283; lasting 0:00:07.747753 seconds
# Epoch: 24500
# Train loss: 0.0281
# dEI: 2.4735
# term1: 3.4029
# term2: 1.5441
# Test multistep loss: 0.0421
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:47:22.814031; lasting 0:00:11.462748 seconds

# %%
# nis+
for e in range(experiments):
    seed = 1 + e
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    spring = Simple_Spring_Model(device=device)
    test_data = spring.generate_multistep_sir(size_list=[500,500], steps=10, sigma=sigma, rou=rou,lam=1,miu=0.5) #sir
    train_data = spring.generate_multistep_sir(size_list=mul_batch_size, steps=steps, sigma=sigma,rou=rou,lam=1,miu=0.5)
    
    eis_nisp, term1s_nisp, term2s_nisp, losses_nisp, MAEs_mstep_nisp = train(train_data=train_data, test_data=test_data, 
                                                                    sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                    mae2_w=mae2_w, T2=T_total,framework='nis+')
    eis_nisp_e[e,:] = eis_nisp
    losses_nisp_e[e,:] = losses_nisp
    MAEs_mstep_nisp_e[e,:] = MAEs_mstep_nisp

# %% [markdown]
# # Generate data

# %%
mul_batch_size = [0,5000,3000,1000]#[0,10,4500,1500]
sigma = 0.03
rou = -0.5
steps = 7

seed = 2050
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
spring = Simple_Spring_Model(device=device)
test_data = spring.generate_multistep_sir(size_list=[500,500], steps=10, sigma=sigma, rou=rou,lam=1,miu=0.5) #sir
train_data = spring.generate_multistep_sir(size_list=mul_batch_size, steps=steps, sigma=sigma,rou=rou,lam=1,miu=0.5)

# %% [markdown]
# # Train NIS

# %%
sz = 4
scale = 2
L = 1
mae2_w = 3
T_total = 30001
eis_nis, term1s_nis, term2s_nis, losses_nis, MAEs_mstep_nis = train(train_data=train_data, test_data=test_data, 
                                                                    sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                    mae2_w=mae2_w, T2=T_total,framework='nis')

# %% [markdown]
# # Train NIS+

# %%
eis_nisp, term1s_nisp, term2s_nisp, losses_nisp, MAEs_mstep_nisp = train(train_data=train_data, test_data=test_data, 
                                                                         sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                         mae2_w=mae2_w, T2=T_total,framework='nis+')

# %% [markdown]
# # Results

# %%
plt.figure(dpi=300)
timeseries = np.arange(len(eis_nis))*500
plt.plot(timeseries, eis_nis, label='NIS')
plt.plot(timeseries, eis_nisp, label='NIS+')
plt.title(r'$\mathcal{J}$')
plt.legend()
plt.show()

# %%
plt.figure(dpi=300)
timeseries = np.arange(len(eis_nis))*500
plt.plot(timeseries, losses_nis, label='NIS')
plt.plot(timeseries, losses_nisp, label='NIS+')
plt.title(r'loss')
plt.legend()
#plt.yscale('log')
plt.show()

# %%
plt.figure(dpi=300)
timeseries = np.arange(len(eis_nis))*500
plt.plot(timeseries, MAEs_mstep_nis, label='NIS')
plt.plot(timeseries, MAEs_mstep_nisp, label='NIS+')
plt.title(r'multistep mae')
plt.legend()
plt.show()
